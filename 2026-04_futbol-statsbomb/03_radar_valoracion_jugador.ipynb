# %% [markdown]
# # **Radar por Percentiles - Qatar 2022**

# %% [markdown]
# - Cargo partidos de Qatar 2022.
#
# - Descargo eventos de todos los partidos.
#
# - Calculo minutos jugados por jugador.
#
# - Asigno posición principal por jugador.
#
# - Construyo métricas ofensivas.
#
# - Llevo métricas de volumen a 90 minutos.
#
# - Filtro jugadores por minutos mínimos y grupo posicional.
#
# - Calculo percentiles dentro del universo elegido.
#
# - Grafico el jugador objetivo con PyPizza.

# %%
from statsbombpy import sb
import pandas as pd
import numpy as np

from mplsoccer import PyPizza
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# parámetros

# %%
nombre_competicion = "FIFA World Cup"
temporada = "2022"

jugador_objetivo = "Kylian Mbappé Lottin"

minutos_minimos = 180
grupo_posicion = "ofensivos"

incluir_penales = False

# %%
metricas_ofensivas = ["goles_p90", "xg_p90", "tiros_p90", "tiros_arco_p90",
    "asistencias_p90", "pases_clave_p90", "pases_progresivos_p90", "conducciones_progresivas_p90",
    "acciones_area_p90", "regates_ok_p90"]

# %%
df_competiciones = sb.competitions()

df_competicion_elegida = df_competiciones[
    (df_competiciones["competition_name"] == nombre_competicion) &
    (df_competiciones["season_name"] == temporada)].copy()

df_competicion_elegida
# Out:
#     competition_id  season_id   country_name competition_name  \
# 29              43        106  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 29               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 29        2022  2024-12-16T10:15:11.055845  2024-12-16T10:21:13.710934
#
#            match_available_360             match_available
# 29  2024-12-16T10:21:13.710934  2024-12-16T10:15:11.055845

# %%
competition_id = df_competicion_elegida["competition_id"].iloc[0]
season_id = df_competicion_elegida["season_id"].iloc[0]

competition_id, season_id
# Out:
# (43, 106)

# %%
df_partidos = sb.matches(competition_id=competition_id,season_id=season_id)

df_partidos.shape
# Out:
# (64, 55)

# %% [markdown]
# partidos

# %%
df_partidos[["match_id", "match_date", "home_team", "away_team", "home_score", "away_score", "competition_stage"]].head()
# Out:
#    match_id  match_date  home_team    away_team  home_score  away_score  \
# 0   3857256  2022-12-02     Serbia  Switzerland           2           3
# 1   3869151  2022-12-03  Argentina    Australia           2           1
# 2   3857257  2022-11-30  Australia      Denmark           1           0
# 3   3857258  2022-11-24     Brazil       Serbia           2           0
# 4   3857288  2022-11-26    Tunisia    Australia           0           1
#
#   competition_stage
# 0       Group Stage
# 1       Round of 16
# 2       Group Stage
# 3       Group Stage
# 4       Group Stage

# %% [markdown]
# eventos

# %%
lista_eventos = []

for match_id in df_partidos["match_id"]:

    df_eventos_partido = sb.events(match_id=match_id)
    df_eventos_partido["match_id"] = match_id
    
    lista_eventos.append(df_eventos_partido)

# %%
df_eventos = pd.concat(lista_eventos, ignore_index=True)

df_eventos.shape
# Out:
# (234652, 114)

# %%
df_eventos["type"].value_counts().head(20)
# Out:
# type
# Pass               68515
# Ball Receipt*      63715
# Carry              53764
# Pressure           16553
# Ball Recovery       5821
# Duel                4389
# Clearance           2684
# Block               2386
# Dribble             1793
# Goal Keeper         1790
# Foul Committed      1775
# Miscontrol          1755
# Foul Won            1693
# Shot                1494
# Dispossessed        1431
# Interception        1371
# Dribbled Past       1036
# Substitution         587
# Injury Stoppage      403
# Half Start           286
# Name: count, dtype: int64

# %%
df_eventos[["match_id", "minute", "second", "team", "player", "position", "type"]].head()
# Out:
#    match_id  minute  second         team player position         type
# 0   3857256       0       0       Serbia    NaN      NaN  Starting XI
# 1   3857256       0       0  Switzerland    NaN      NaN  Starting XI
# 2   3857256       0       0  Switzerland    NaN      NaN   Half Start
# 3   3857256       0       0       Serbia    NaN      NaN   Half Start
# 4   3857256      45       0       Serbia    NaN      NaN   Half Start

# %% [markdown]
# eventos asociados a un jugador

# %%
df_eventos_jugador = df_eventos[df_eventos["player"].notna()].copy()

df_eventos_jugador.shape
# Out:
# (233544, 114)

# %%
df_eventos_jugador["position"].dropna().sort_values().unique()
# Out:
# array(['Center Attacking Midfield', 'Center Back',
#        'Center Defensive Midfield', 'Center Forward', 'Goalkeeper',
#        'Left Attacking Midfield', 'Left Back', 'Left Center Back',
#        'Left Center Forward', 'Left Center Midfield',
#        'Left Defensive Midfield', 'Left Midfield', 'Left Wing',
#        'Left Wing Back', 'Right Attacking Midfield', 'Right Back',
#        'Right Center Back', 'Right Center Forward',
#        'Right Center Midfield', 'Right Defensive Midfield',
#        'Right Midfield', 'Right Wing', 'Right Wing Back', 'Substitute'],
#       dtype=object)

# %% [markdown]
# separo posiciones

# %%
#   posiciones_por_grupo = {
#       "ofensivos": ["Center Forward","Left Wing","Right Wing","Secondary Striker","Attacking Midfield"],
#       "mediocampistas": ["Center Midfield","Defensive Midfield","Left Midfield","Right Midfield","Left Center Midfield","Right Center Midfield"],
#       "laterales": ["Left Back","Right Back","Left Wing Back","Right Wing Back"],
#       "centrales": ["Center Back","Left Center Back","Right Center Back"],
#       "arqueros": ["Goalkeeper"],
#       "todos": []}

# %%
posiciones_por_grupo = {
    "ofensivos": ["Center Forward","Left Center Forward","Right Center Forward","Left Wing","Right Wing","Secondary Striker","Attacking Midfield","Center Attacking Midfield","Left Attacking Midfield","Right Attacking Midfield"],
    "mediocampistas": ["Center Midfield","Defensive Midfield","Left Midfield","Right Midfield","Left Center Midfield","Right Center Midfield"],
    "laterales": ["Left Back","Right Back","Left Wing Back","Right Wing Back"],
    "centrales": ["Center Back","Left Center Back","Right Center Back"],
    "arqueros": ["Goalkeeper"],
    "todos": []}

# %% [markdown]
# si no elijo alguna posición, me llevo todas al cálculo

# %%
if grupo_posicion == "todos":
    df_base_grupo = df_eventos_jugador.copy()
else:
    posiciones_elegidas = posiciones_por_grupo[grupo_posicion]
    
    df_base_grupo = df_eventos_jugador[df_eventos_jugador["position"].isin(posiciones_elegidas)].copy()

df_base_grupo.shape
# Out:
# (54735, 114)

# %%
df_base_grupo["position"].value_counts()
# Out:
# position
# Right Wing                   12207
# Left Wing                    12166
# Center Forward               11263
# Center Attacking Midfield     7520
# Left Center Forward           4785
# Right Center Forward          4766
# Left Attacking Midfield       1028
# Right Attacking Midfield      1000
# Name: count, dtype: int64

# %% [markdown]
# calculo minutos totales del partido sin contar la tanda de penales

# %%
df_eventos["second"] = df_eventos["second"].fillna(0)

df_eventos["minuto_juego"] = (df_eventos["minute"] + df_eventos["second"] / 60)

df_fin_partido = (df_eventos[df_eventos["period"] <= 4].groupby("match_id", as_index=False).agg(minuto_final=("minuto_juego", "max")))

df_fin_partido.head()
# Out:
#    match_id  minuto_final
# 0   3857254     97.600000
# 1   3857255     97.016667
# 2   3857256    100.300000
# 3   3857257     96.050000
# 4   3857258     97.133333

# %% [markdown]
# alineaciones y posiciones

# %%
lista_lineups = []

for match_id in df_partidos["match_id"]:
    
    lineups_partido = sb.lineups(match_id=match_id)
    
    for equipo, df_equipo in lineups_partido.items():
        
        df_equipo = df_equipo.copy()
        df_equipo["team"] = equipo
        df_equipo["match_id"] = match_id
        
        lista_lineups.append(df_equipo)

# %%
df_lineups = pd.concat(lista_lineups, ignore_index=True)

df_lineups.shape
# Out:
# (3244, 9)

# %%
df_posiciones = df_lineups[["match_id", "team", "player_id", "player_name", "positions"]].explode("positions").copy()

df_posiciones = df_posiciones[df_posiciones["positions"].notna()].copy()

df_posiciones_detalle = pd.concat([
        df_posiciones.drop(columns="positions").reset_index(drop=True),
        pd.json_normalize(df_posiciones["positions"]).reset_index(drop=True)],axis=1)

df_posiciones_detalle.head()
# Out:
#    match_id         team  player_id          player_name  position_id  \
# 0   3857256  Switzerland       3500         Granit Xhaka           11
# 1   3857256  Switzerland       3533      Xherdan Shaqiri           17
# 2   3857256  Switzerland       3913  Edimilson Fernandes           19
# 3   3857256  Switzerland       3913  Edimilson Fernandes           17
# 4   3857256  Switzerland       5537   Fabian Lukas Schär            3
#
#                     position   from     to  from_period  to_period  \
# 0    Left Defensive Midfield  00:00   None            1        NaN
# 1                 Right Wing  00:00  68:17            1        2.0
# 2  Center Attacking Midfield  67:51  68:21            2        2.0
# 3                 Right Wing  68:21   None            2        NaN
# 4          Right Center Back  00:00   None            1        NaN
#
#                    start_reason                     end_reason
# 0                   Starting XI                  Final Whistle
# 1                   Starting XI  Substitution - Off (Tactical)
# 2  Substitution - On (Tactical)                 Tactical Shift
# 3                Tactical Shift                  Final Whistle
# 4                   Starting XI                  Final Whistle

# %%
def convertir_tiempo_a_minutos(valor):
    
    if pd.isna(valor):
        return np.nan
    
    partes = str(valor).split(":")
    
    if len(partes) == 2:
        minutos = float(partes[0])
        segundos = float(partes[1])
        return minutos + segundos / 60
    
    if len(partes) == 3:
        horas = float(partes[0])
        minutos = float(partes[1])
        segundos = float(partes[2])
        return horas * 60 + minutos + segundos / 60
    
    return np.nan

# %%
df_posiciones_detalle = df_posiciones_detalle.merge(
    df_fin_partido,
    on="match_id",
    how="left"
)

df_posiciones_detalle["minuto_desde"] = (
    df_posiciones_detalle["from"]
    .apply(convertir_tiempo_a_minutos)
    .fillna(0)
)

df_posiciones_detalle["minuto_hasta"] = (
    df_posiciones_detalle["to"]
    .apply(convertir_tiempo_a_minutos)
)

df_posiciones_detalle["minuto_hasta"] = (
    df_posiciones_detalle["minuto_hasta"]
    .fillna(df_posiciones_detalle["minuto_final"])
)

df_posiciones_detalle["minutos_jugados"] = (
    df_posiciones_detalle["minuto_hasta"] -
    df_posiciones_detalle["minuto_desde"]
).clip(lower=0)

df_posiciones_detalle[
    ["player_name", "team", "position", "minuto_desde", "minuto_hasta", "minutos_jugados"]
].head(20)
# Out:
#                      player_name         team                   position  \
# 0                   Granit Xhaka  Switzerland    Left Defensive Midfield
# 1                Xherdan Shaqiri  Switzerland                 Right Wing
# 2            Edimilson Fernandes  Switzerland  Center Attacking Midfield
# 3            Edimilson Fernandes  Switzerland                 Right Wing
# 4             Fabian Lukas Schär  Switzerland          Right Center Back
# 5   Denis Lemi Zakaria Lako Lado  Switzerland                 Right Wing
# 6   Denis Lemi Zakaria Lako Lado  Switzerland   Right Defensive Midfield
# 7   Ricardo Iván Rodríguez Araya  Switzerland                  Left Back
# 8            Breel-Donald Embolo  Switzerland             Center Forward
# 9          Manuel Obafemi Akanji  Switzerland           Left Center Back
# 10                  Remo Freuler  Switzerland   Right Defensive Midfield
# 11                  Remo Freuler  Switzerland  Center Attacking Midfield
# 12                 Silvan Widmer  Switzerland                 Right Back
# 13           Christian Fassnacht  Switzerland                  Left Wing
# 14                   Djibril Sow  Switzerland  Center Attacking Midfield
# 15                  Gregor Kobel  Switzerland                 Goalkeeper
# 16                   Noah Okafor  Switzerland             Center Forward
# 17                  Ruben Vargas  Switzerland                  Left Wing
# 18                   Dušan Tadić       Serbia  Center Attacking Midfield
# 19           Aleksandar Mitrović       Serbia        Left Center Forward
#
#     minuto_desde  minuto_hasta  minutos_jugados
# 0       0.000000    100.300000       100.300000
# 1       0.000000     68.283333        68.283333
# 2      67.850000     68.350000         0.500000
# 3      68.350000    100.300000        31.950000
# 4       0.000000    100.300000       100.300000
# 5      68.283333     68.350000         0.066667
# 6      68.350000    100.300000        31.950000
# 7       0.000000    100.300000       100.300000
# 8       0.000000     95.400000        95.400000
# 9       0.000000    100.300000       100.300000
# 10      0.000000     68.350000        68.350000
# 11     68.350000    100.300000        31.950000
# 12      0.000000    100.300000       100.300000
# 13     82.850000    100.300000        17.450000
# 14      0.000000     67.850000        67.850000
# 15      0.000000    100.300000       100.300000
# 16     95.400000    100.300000         4.900000
# 17      0.000000     82.850000        82.850000
# 18      0.000000     77.583333        77.583333
# 19      0.000000    100.300000       100.300000

# %%
df_minutos = (
    df_posiciones_detalle
    .groupby(["player_name", "team"], as_index=False)
    .agg(minutos_jugados=("minutos_jugados", "sum"))
    .rename(columns={"player_name": "player"})
)

df_minutos = df_minutos.sort_values(
    "minutos_jugados",
    ascending=False
)

df_minutos.head(20)
# Out:
#                              player       team  minutos_jugados
# 384  Lionel Andrés Messi Cuccittini  Argentina       867.600000
# 487         Nicolás Hernán Otamendi  Argentina       780.383333
# 271                    Ivan Perišić    Croatia       747.683333
# 589                  Sofyan Amrabat    Morocco       734.083333
# 141        Damián Emiliano Martínez  Argentina       733.900000
# 171               Dominik Livaković    Croatia       720.283333
# 329                  Joško Gvardiol    Croatia       720.283333
# 16               Achraf Hakimi Mouh    Morocco       696.500000
# 393                     Luka Modrić    Croatia       672.666667
# 75        Aurélien Djani Tchouaméni     France       661.666667
# 237                    Hakim Ziyech    Morocco       661.500000
# 374            Kylian Mbappé Lottin     France       653.583333
# 415                   Mateo Kovačić    Croatia       649.916667
# 464            Nahuel Molina Lucero  Argentina       648.700000
# 544          Rodrigo Javier De Paul  Argentina       634.566667
# 83                  Azzedine Ounahi    Morocco       627.916667
# 526                  Raphaël Varane     France       627.383333
# 161                    Dejan Lovren    Croatia       624.133333
# 317                 Josip Juranović    Croatia       624.133333
# 256                     Hugo Lloris     France       614.200000

# %%
df_posicion_principal = (
    df_posiciones_detalle
    .groupby(["player_name", "team", "position"], as_index=False)
    .agg(minutos_posicion=("minutos_jugados", "sum"))
    .sort_values(["player_name", "team", "minutos_posicion"], ascending=[True, True, False])
    .drop_duplicates(["player_name", "team"])
    .rename(columns={"player_name": "player", "position": "posicion_principal"})
)

df_minutos = df_minutos.merge(
    df_posicion_principal[["player", "team", "posicion_principal"]],
    on=["player", "team"],
    how="left"
)

df_minutos.head()
# Out:
#                            player       team  minutos_jugados  \
# 0  Lionel Andrés Messi Cuccittini  Argentina       867.600000
# 1         Nicolás Hernán Otamendi  Argentina       780.383333
# 2                    Ivan Perišić    Croatia       747.683333
# 3                  Sofyan Amrabat    Morocco       734.083333
# 4        Damián Emiliano Martínez  Argentina       733.900000
#
#           posicion_principal
# 0       Right Center Forward
# 1           Left Center Back
# 2                  Left Wing
# 3  Center Defensive Midfield
# 4                 Goalkeeper

# %%
def asignar_grupo_posicion(posicion):
    
    for grupo, posiciones in posiciones_por_grupo.items():
        
        if grupo == "todos":
            continue
        
        if posicion in posiciones:
            return grupo
    
    return "otros"


df_minutos["grupo_posicion"] = (
    df_minutos["posicion_principal"]
    .apply(asignar_grupo_posicion)
)

df_minutos["grupo_posicion"].value_counts()
# Out:
# grupo_posicion
# ofensivos         225
# laterales         118
# centrales         116
# otros             103
# mediocampistas     77
# arqueros           41
# Name: count, dtype: int64

# %%
df_metricas = df_eventos_jugador.copy()

df_metricas[["x", "y"]] = df_metricas["location"].apply(pd.Series)

df_metricas[["pass_x_fin", "pass_y_fin"]] = (
    df_metricas["pass_end_location"]
    .apply(pd.Series)
)

df_metricas[["carry_x_fin", "carry_y_fin"]] = (
    df_metricas["carry_end_location"]
    .apply(pd.Series)
)

# %%
x_ultimo_tercio = 80
x_area = 102
y_area_min = 18
y_area_max = 62
umbral_progresion = 10

resultados_tiro_arco = [
    "Goal",
    "Saved",
    "Saved to Post"
]

# %%
es_penal = df_metricas["shot_type"] == "Penalty"

if incluir_penales:
    tiro_valido = df_metricas["type"] == "Shot"
else:
    tiro_valido = (df_metricas["type"] == "Shot") & (~es_penal)

df_metricas["goles"] = np.where(
    tiro_valido & (df_metricas["shot_outcome"] == "Goal"),
    1,
    0
)

df_metricas["tiros"] = np.where(
    tiro_valido,
    1,
    0
)

df_metricas["tiros_arco"] = np.where(
    tiro_valido & df_metricas["shot_outcome"].isin(resultados_tiro_arco),
    1,
    0
)

df_metricas["xg"] = np.where(
    tiro_valido,
    df_metricas["shot_statsbomb_xg"].fillna(0),
    0
)

df_metricas["asistencias"] = np.where(
    df_metricas["pass_goal_assist"] == True,
    1,
    0
)

df_metricas["pases_clave"] = np.where(
    df_metricas["pass_shot_assist"] == True,
    1,
    0
)

df_metricas["pases_progresivos"] = np.where(
    (df_metricas["type"] == "Pass") &
    (df_metricas["pass_outcome"].isna()) &
    ((df_metricas["pass_x_fin"] - df_metricas["x"]) >= umbral_progresion),
    1,
    0
)

df_metricas["conducciones_progresivas"] = np.where(
    (df_metricas["type"] == "Carry") &
    ((df_metricas["carry_x_fin"] - df_metricas["x"]) >= umbral_progresion),
    1,
    0
)

df_metricas["acciones_area"] = np.where(
    (df_metricas["x"] >= x_area) &
    (df_metricas["y"].between(y_area_min, y_area_max)),
    1,
    0
)

df_metricas["acciones_ultimo_tercio"] = np.where(
    df_metricas["x"] >= x_ultimo_tercio,
    1,
    0
)

df_metricas["regates_ok"] = np.where(
    (df_metricas["type"] == "Dribble") &
    (df_metricas["dribble_outcome"] == "Complete"),
    1,
    0
)

# %%
df_metricas_jugador = (
    df_metricas
    .groupby(["player", "team"], as_index=False)
    .agg(
        goles=("goles", "sum"),
        xg=("xg", "sum"),
        tiros=("tiros", "sum"),
        tiros_arco=("tiros_arco", "sum"),
        asistencias=("asistencias", "sum"),
        pases_clave=("pases_clave", "sum"),
        pases_progresivos=("pases_progresivos", "sum"),
        conducciones_progresivas=("conducciones_progresivas", "sum"),
        acciones_area=("acciones_area", "sum"),
        acciones_ultimo_tercio=("acciones_ultimo_tercio", "sum"),
        regates_ok=("regates_ok", "sum")
    )
)

df_metricas_jugador.head()
# Out:
#                               player       team  goles        xg  tiros  \
# 0                         Aaron Mooy  Australia      0  0.039191      1
# 1                       Aaron Ramsey      Wales      0  0.025361      1
# 2                  Abdelhamid Sabiri    Morocco      0  0.123384      3
# 3  Abdelkarim Hassan Al Haj Fadlalla      Qatar      0  0.274915      6
# 4               Abderrazak Hamdallah    Morocco      0  0.542997      2
#
#    tiros_arco  asistencias  pases_clave  pases_progresivos  \
# 0           0            0            1                 49
# 1           0            0            1                 14
# 2           0            1            2                  4
# 3           0            0            1                 41
# 4           1            0            0                  2
#
#    conducciones_progresivas  acciones_area  acciones_ultimo_tercio  regates_ok
# 0                        12              0                      95           2
# 1                         4             24                     136           3
# 2                         4              4                      40           0
# 3                        34              8                      55           2
# 4                         4             17                      54           1

# %%
df_radar_base = df_metricas_jugador.merge(
    df_minutos,
    on=["player", "team"],
    how="left"
)

df_radar_base = df_radar_base[
    df_radar_base["minutos_jugados"].notna()
].copy()

df_radar_base.head()
# Out:
#                               player       team  goles        xg  tiros  \
# 0                         Aaron Mooy  Australia      0  0.039191      1
# 1                       Aaron Ramsey      Wales      0  0.025361      1
# 2                  Abdelhamid Sabiri    Morocco      0  0.123384      3
# 3  Abdelkarim Hassan Al Haj Fadlalla      Qatar      0  0.274915      6
# 4               Abderrazak Hamdallah    Morocco      0  0.542997      2
#
#    tiros_arco  asistencias  pases_clave  pases_progresivos  \
# 0           0            0            1                 49
# 1           0            0            1                 14
# 2           0            1            2                  4
# 3           0            0            1                 41
# 4           1            0            0                  2
#
#    conducciones_progresivas  acciones_area  acciones_ultimo_tercio  \
# 0                        12              0                      95
# 1                         4             24                     136
# 2                         4              4                      40
# 3                        34              8                      55
# 4                         4             17                      54
#
#    regates_ok  minutos_jugados       posicion_principal  grupo_posicion
# 0           2       386.916667  Left Defensive Midfield           otros
# 1           3       281.383333    Right Center Midfield  mediocampistas
# 2           0       194.333333     Left Center Midfield  mediocampistas
# 3           2       287.400000         Left Center Back       centrales
# 4           1        87.400000           Center Forward       ofensivos

# %%
metricas_volumen = [
    "goles",
    "xg",
    "tiros",
    "tiros_arco",
    "asistencias",
    "pases_clave",
    "pases_progresivos",
    "conducciones_progresivas",
    "acciones_area",
    "acciones_ultimo_tercio",
    "regates_ok"
]

for metrica in metricas_volumen:
    
    df_radar_base[metrica + "_p90"] = (
        df_radar_base[metrica] /
        df_radar_base["minutos_jugados"] *
        90
    )

df_radar_base.head()
# Out:
#                               player       team  goles        xg  tiros  \
# 0                         Aaron Mooy  Australia      0  0.039191      1
# 1                       Aaron Ramsey      Wales      0  0.025361      1
# 2                  Abdelhamid Sabiri    Morocco      0  0.123384      3
# 3  Abdelkarim Hassan Al Haj Fadlalla      Qatar      0  0.274915      6
# 4               Abderrazak Hamdallah    Morocco      0  0.542997      2
#
#    tiros_arco  asistencias  pases_clave  pases_progresivos  \
# 0           0            0            1                 49
# 1           0            0            1                 14
# 2           0            1            2                  4
# 3           0            0            1                 41
# 4           1            0            0                  2
#
#    conducciones_progresivas  acciones_area  acciones_ultimo_tercio  \
# 0                        12              0                      95
# 1                         4             24                     136
# 2                         4              4                      40
# 3                        34              8                      55
# 4                         4             17                      54
#
#    regates_ok  minutos_jugados       posicion_principal  grupo_posicion  \
# 0           2       386.916667  Left Defensive Midfield           otros
# 1           3       281.383333    Right Center Midfield  mediocampistas
# 2           0       194.333333     Left Center Midfield  mediocampistas
# 3           2       287.400000         Left Center Back       centrales
# 4           1        87.400000           Center Forward       ofensivos
#
#    goles_p90    xg_p90  tiros_p90  tiros_arco_p90  asistencias_p90  \
# 0        0.0  0.009116   0.232608        0.000000         0.000000
# 1        0.0  0.008112   0.319848        0.000000         0.000000
# 2        0.0  0.057142   1.389365        0.000000         0.463122
# 3        0.0  0.086090   1.878914        0.000000         0.000000
# 4        0.0  0.559150   2.059497        1.029748         0.000000
#
#    pases_clave_p90  pases_progresivos_p90  conducciones_progresivas_p90  \
# 0         0.232608              11.397803                      2.791299
# 1         0.319848               4.477877                      1.279393
# 2         0.926244               1.852487                      1.852487
# 3         0.313152              12.839248                     10.647182
# 4         0.000000               2.059497                      4.118993
#
#    acciones_area_p90  acciones_ultimo_tercio_p90  regates_ok_p90
# 0           0.000000                   22.097782        0.465216
# 1           7.676361                   43.499378        0.959545
# 2           1.852487                   18.524871        0.000000
# 3           2.505219                   17.223382        0.626305
# 4          17.505721                   55.606407        1.029748

# %%
df_universo = df_radar_base[
    df_radar_base["minutos_jugados"] >= minutos_minimos
].copy()

if grupo_posicion != "todos":
    df_universo = df_universo[
        df_universo["grupo_posicion"] == grupo_posicion
    ].copy()

df_universo.shape
# Out:
# (87, 27)

# %%
df_universo[
    ["player", "team", "minutos_jugados", "posicion_principal", "grupo_posicion"]
].sort_values("minutos_jugados", ascending=False).head(20)
# Out:
#                              player         team  minutos_jugados  \
# 384  Lionel Andrés Messi Cuccittini    Argentina       867.600000
# 272                    Ivan Perišić      Croatia       747.683333
# 238                    Hakim Ziyech      Morocco       661.500000
# 374            Kylian Mbappé Lottin       France       653.583333
# 64                Antoine Griezmann       France       586.050000
# 661               Youssef En-Nesyri      Morocco       553.816667
# 130               Cody Mathès Gakpo  Netherlands       536.266667
# 336                  Julián Álvarez    Argentina       485.233333
# 52                  Andrej Kramarić      Croatia       477.833333
# 589                  Sofiane Boufal      Morocco       476.533333
# 501                 Ousmane Dembélé       France       448.000000
# 497                  Olivier Giroud       France       432.616667
# 241                      Harry Kane      England       421.133333
# 540              Robert Lewandowski       Poland       389.750000
# 251                   Heung-Min Son  South Korea       389.650000
# 148            Daniel Olmo Carvajal        Spain       388.250000
# 103   Bruno Miguel Borges Fernandes     Portugal       384.950000
# 269                    Ismaïla Sarr      Senegal       365.200000
# 326             João Félix Sequeira     Portugal       340.233333
# 138                   Daichi Kamada        Japan       337.216667
#
#             posicion_principal grupo_posicion
# 384       Right Center Forward      ofensivos
# 272                  Left Wing      ofensivos
# 238                 Right Wing      ofensivos
# 374                  Left Wing      ofensivos
# 64   Center Attacking Midfield      ofensivos
# 661             Center Forward      ofensivos
# 130       Right Center Forward      ofensivos
# 336        Left Center Forward      ofensivos
# 52                  Right Wing      ofensivos
# 589                  Left Wing      ofensivos
# 501                 Right Wing      ofensivos
# 497             Center Forward      ofensivos
# 241             Center Forward      ofensivos
# 540             Center Forward      ofensivos
# 251                  Left Wing      ofensivos
# 148                  Left Wing      ofensivos
# 103                 Right Wing      ofensivos
# 269                  Left Wing      ofensivos
# 326                  Left Wing      ofensivos
# 138                  Left Wing      ofensivos

# %%
metricas_radar = [
    "goles_p90",
    "xg_p90",
    "tiros_p90",
    "tiros_arco_p90",
    "asistencias_p90",
    "pases_clave_p90",
    "pases_progresivos_p90",
    "conducciones_progresivas_p90",
    "acciones_area_p90",
    "acciones_ultimo_tercio_p90",
    "regates_ok_p90"
]

nombres_metricas = {
    "goles_p90": "Goles",
    "xg_p90": "xG",
    "tiros_p90": "Tiros",
    "tiros_arco_p90": "Tiros\nal arco",
    "asistencias_p90": "Asist.",
    "pases_clave_p90": "Pases\nclave",
    "pases_progresivos_p90": "Pases\nprog.",
    "conducciones_progresivas_p90": "Conduc.\nprog.",
    "acciones_area_p90": "Acc.\nárea",
    "acciones_ultimo_tercio_p90": "Acc. último\ntercio",
    "regates_ok_p90": "Regates\nOK"
}

# %%
df_percentiles = df_universo.copy()

for metrica in metricas_radar:
    
    nombre_percentil = metrica + "_percentil"
    
    df_percentiles[nombre_percentil] = (
        df_percentiles[metrica]
        .rank(pct=True) * 100
    )

df_percentiles.head()
# Out:
#                               player     team  goles        xg  tiros  \
# 22                 Akram Hassan Afif    Qatar      0  0.029100      2
# 26               Aleksandar Mitrović   Serbia      2  1.501642     10
# 44  Almoez Ali Zainalabiddin Abdulla    Qatar      0  0.483816      3
# 52                   Andrej Kramarić  Croatia      2  1.087257     10
# 55                   André Ayew Pelé    Ghana      1  0.485245      1
#
#     tiros_arco  asistencias  pases_clave  pases_progresivos  \
# 22           0            0            5                 31
# 26           3            0            1                  8
# 44           1            0            0                  3
# 52           4            0            5                  7
# 55           1            0            0                  2
#
#     conducciones_progresivas  acciones_area  acciones_ultimo_tercio  \
# 22                        15             10                     162
# 26                         2             64                     147
# 44                         4             30                     100
# 52                        13             65                     351
# 55                         1             18                      69
#
#     regates_ok  minutos_jugados         posicion_principal grupo_posicion  \
# 22           3       287.400000        Left Center Forward      ofensivos
# 26           1       279.200000             Center Forward      ofensivos
# 44           3       231.400000       Right Center Forward      ofensivos
# 52           3       477.833333                 Right Wing      ofensivos
# 55           0       199.150000  Center Attacking Midfield      ofensivos
#
#     goles_p90    xg_p90  tiros_p90  tiros_arco_p90  asistencias_p90  \
# 22   0.000000  0.009113   0.626305        0.000000              0.0
# 26   0.644699  0.484054   3.223496        0.967049              0.0
# 44   0.000000  0.188174   1.166811        0.388937              0.0
# 52   0.376700  0.204785   1.883502        0.753401              0.0
# 55   0.451921  0.219292   0.451921        0.451921              0.0
#
#     pases_clave_p90  pases_progresivos_p90  conducciones_progresivas_p90  \
# 22         1.565762               9.707724                      4.697286
# 26         0.322350               2.578797                      0.644699
# 44         0.000000               1.166811                      1.555748
# 52         0.941751               1.318451                      2.448552
# 55         0.000000               0.903841                      0.451921
#
#     acciones_area_p90  acciones_ultimo_tercio_p90  regates_ok_p90  \
# 22           3.131524                   50.730689        0.939457
# 26          20.630372                   47.385387        0.322350
# 44          11.668107                   38.893691        1.166811
# 52          12.242762                   66.110917        0.565051
# 55           8.134572                   31.182526        0.000000
#
#     goles_p90_percentil  xg_p90_percentil  tiros_p90_percentil  \
# 22            22.988506          3.448276            10.344828
# 26            89.655172         94.252874            86.206897
# 44            22.988506         52.873563            26.436782
# 52            72.413793         56.321839            52.873563
# 55            80.459770         58.620690             8.045977
#
#     tiros_arco_p90_percentil  asistencias_p90_percentil  \
# 22                  8.045977                  35.632184
# 26                 70.114943                  35.632184
# 44                 28.735632                  35.632184
# 52                 55.172414                  35.632184
# 55                 37.931034                  35.632184
#
#     pases_clave_p90_percentil  pases_progresivos_p90_percentil  \
# 22                  78.160920                        97.701149
# 26                  24.137931                        42.528736
# 44                   7.471264                        14.942529
# 52                  59.770115                        19.540230
# 55                   7.471264                         8.045977
#
#     conducciones_progresivas_p90_percentil  acciones_area_p90_percentil  \
# 22                               75.862069                     3.448276
# 26                                8.045977                    91.954023
# 44                               18.390805                    58.620690
# 52                               36.781609                    60.919540
# 55                                4.597701                    33.333333
#
#     acciones_ultimo_tercio_p90_percentil  regates_ok_p90_percentil
# 22                             21.839080                 51.724138
# 26                             19.540230                 20.689655
# 44                             11.494253                 65.517241
# 52                             62.068966                 32.183908
# 55                              4.597701                  8.045977

# %%
df_jugador = df_percentiles[
    df_percentiles["player"] == jugador_objetivo
].copy()

df_jugador[
    ["player", "team", "minutos_jugados", "posicion_principal", "grupo_posicion"]
]
# Out:
#                    player    team  minutos_jugados posicion_principal  \
# 374  Kylian Mbappé Lottin  France       653.583333          Left Wing
#
#     grupo_posicion
# 374      ofensivos

# %%
params = [nombres_metricas[metrica] for metrica in metricas_radar]

valores = []

for metrica in metricas_radar:
    
    nombre_percentil = metrica + "_percentil"
    
    valor = df_jugador[nombre_percentil].iloc[0]
    valor = round(valor, 1)
    
    valores.append(valor)

params, valores
# Out:
# (['Goles',
#   'xG',
#   'Tiros',
#   'Tiros\nal arco',
#   'Asist.',
#   'Pases\nclave',
#   'Pases\nprog.',
#   'Conduc.\nprog.',
#   'Acc.\nárea',
#   'Acc. último\ntercio',
#   'Regates\nOK'],
#  [96.6, 86.2, 96.6, 95.4, 75.9, 66.7, 73.6, 96.6, 89.7, 94.3, 97.7])

# %%
colores_porcion = [
    "#E4002B", "#E4002B", "#E4002B", "#E4002B",
    "#FF8700", "#FF8700", "#FF8700",
    "#1E88E5", "#1E88E5", "#a432c7", "#a432c7"
]

colores_texto = [
    "white", "white", "white", "white",
    "black", "black", "black",
    "white", "white", "black", "black"
]

# %%
fuente_grafico = "DejaVu Sans"

pizza = PyPizza(
    params=params,
    background_color="#E5E5E5",
    straight_line_color="#E5E5E5",
    straight_line_lw=1,
    last_circle_lw=0,
    other_circle_lw=1,
    other_circle_color="#D0D0D0",
    inner_circle_size=40)

fig, ax = pizza.make_pizza(
    valores,
    figsize=(11, 12),
    color_blank_space="same",
    slice_colors=colores_porcion,
    value_colors=colores_texto,
    value_bck_colors=colores_porcion,
    param_location=115,
    kwargs_slices=dict(
        edgecolor="#E5E5E5",
        linewidth=1),
    kwargs_params=dict(
        color="#111827",
        fontsize=12,
        fontweight="bold",
        fontfamily=fuente_grafico),
    kwargs_values=dict(
        color="#111827",
        fontsize=12,
        fontweight="bold",
        fontfamily=fuente_grafico,
        bbox=dict(
            edgecolor="#111827",
            facecolor="#E5E5E5",
            boxstyle="round,pad=0.2",
            linewidth=0.8)))

fig.set_facecolor("#E5E5E5")

fig.text(
    0.5,
    0.97,
    jugador_objetivo,
    ha="center",
    fontsize=35,
    fontweight="bold",
    fontfamily=fuente_grafico,
    color="#1E88E5")

fig.text(
    0.5,
    0.94,
    f"Radar ofensivo | Percentiles vs. {grupo_posicion} | Mundial Qatar 2022",
    ha="center",
    fontsize=15,
    fontfamily=fuente_grafico,
    color="#333333")

fig.text(
    0.5,
    0.92,
    f"Mínimo {minutos_minimos} minutos | Métricas por 90 minutos",
    ha="center",
    fontsize=12,
    fontfamily=fuente_grafico,
    color="#555555")

plt.show()

# %%
columnas_resumen = [
    "player",
    "team",
    "minutos_jugados",
    "posicion_principal"
]

for metrica in metricas_radar:
    columnas_resumen.append(metrica)
    columnas_resumen.append(metrica + "_percentil")

df_jugador[columnas_resumen].T
# Out:
#                                                          374
# player                                  Kylian Mbappé Lottin
# team                                                  France
# minutos_jugados                                   653.583333
# posicion_principal                                 Left Wing
# goles_p90                                           0.826214
# goles_p90_percentil                                96.551724
# xg_p90                                              0.367149
# xg_p90_percentil                                   86.206897
# tiros_p90                                            3.99337
# tiros_p90_percentil                                96.551724
# tiros_arco_p90                                      1.514727
# tiros_arco_p90_percentil                           95.402299
# asistencias_p90                                     0.275405
# asistencias_p90_percentil                          75.862069
# pases_clave_p90                                     1.239322
# pases_clave_p90_percentil                          66.666667
# pases_progresivos_p90                               4.406477
# pases_progresivos_p90_percentil                    73.563218
# conducciones_progresivas_p90                        7.573633
# conducciones_progresivas_p90_percentil             96.551724
# acciones_area_p90                                  19.829147
# acciones_area_p90_percentil                        89.655172
# acciones_ultimo_tercio_p90                         94.739258
# acciones_ultimo_tercio_p90_percentil               94.252874
# regates_ok_p90                                      4.131072
# regates_ok_p90_percentil                           97.701149

# %%
df_minutos[
    df_minutos["player"].str.contains("Messi", case=False, na=False)
][
    ["player", "team", "minutos_jugados", "posicion_principal", "grupo_posicion"]
]
# Out:
#                            player       team  minutos_jugados  \
# 0  Lionel Andrés Messi Cuccittini  Argentina            867.6
#
#      posicion_principal grupo_posicion
# 0  Right Center Forward      ofensivos

# %%
df_posiciones_detalle[
    df_posiciones_detalle["player_name"].str.contains("Messi", case=False, na=False)
][
    ["player_name", "team", "position", "minutos_jugados"]
].sort_values("minutos_jugados", ascending=False)
# Out:
#                          player_name       team              position  \
# 478   Lionel Andrés Messi Cuccittini  Argentina            Right Wing
# 322   Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 1741  Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 656   Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 480   Lionel Andrés Messi Cuccittini  Argentina            Right Wing
# 930   Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 40    Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 566   Lionel Andrés Messi Cuccittini  Argentina        Center Forward
# 324   Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
# 567   Lionel Andrés Messi Cuccittini  Argentina            Right Wing
# 39    Lionel Andrés Messi Cuccittini  Argentina        Center Forward
# 323   Lionel Andrés Messi Cuccittini  Argentina        Center Forward
# 479   Lionel Andrés Messi Cuccittini  Argentina  Right Center Forward
#
#       minutos_jugados
# 478        115.533333
# 322        112.833333
# 1741       103.833333
# 656         96.483333
# 480         95.800000
# 930         95.033333
# 40          70.400000
# 566         59.433333
# 324         54.700000
# 567         36.583333
# 39          26.966667
# 323          0.000000
# 479          0.000000
